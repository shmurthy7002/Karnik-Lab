# %%
import pandas as pd

df = pd.read_csv('yhtrum7002_gmail.com5765.tsv', sep='\t')

# %%
wanted_columns = ['IC50 (nM)', 'Ligand SMILES', 'Ki (nM)', 'Kd (nM)', 'EC50 (nM)']
df = df[wanted_columns]
print(df.columns)
# Out:
# Index(['IC50 (nM)', 'Ligand SMILES', 'Ki (nM)', 'Kd (nM)', 'EC50 (nM)'], dtype='object')

# %%
print("Values that are not null")
for column in df.columns:
    print(f"{column} : {df[column].notna().sum()}")
# Out:
# Values that are not null
# IC50 (nM) : 3268
# Ligand SMILES : 4045
# Ki (nM) : 538
# Kd (nM) : 121
# EC50 (nM) : 118

# %%
# count = 0
# for Ki in df['Ki (nM)']:
#     if float(Ki) < 5000: count +=1

# print(f"{count} Ki values below 5 mM")
df['j'] = df['Ki (nM)'].str.replace(r'^[><]', '', regex=True)
# Out:
# C:\Users\yhtru\AppData\Local\Temp\ipykernel_14796\4102180124.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['column_name'] = df['Ki (nM)'].str.replace(r'^[><]', '', regex=True)

# %%
count = 0
for val in df['column_name']:
    if float(val) < 5000:
        count += 1
print(count)
# Out:
# 423
